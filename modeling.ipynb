# %%
import pandas as pd
import plotly

# %%
df = pd.read_csv('lasttimeinBOtop10.csv')
df
# Out:
#       Unnamed: 0.2  Unnamed: 0.1   movieCd  Unnamed: 0        date  rnum  \
# 0                0             0  20223308       15328  2022-03-13     9
# 1                1             1  20196201        9258  2020-07-14     9
# 2                2             2  20208282        8838  2020-06-02     9
# 3                3             3  20188304        2726  2018-09-30     7
# 4                4             4  20173226       11859  2021-03-31    10
# ...            ...           ...       ...         ...         ...   ...
# 1387          1387          1387  20204432       10513  2020-11-17     4
# 1388          1388          1388  20200065       12049  2021-04-19    10
# 1389          1389          1389  20191951       13318  2021-08-24     9
# 1390          1390          1390  20179228         348  2018-02-04     9
# 1391          1391          1391  20224634       16499  2022-07-08    10
#
#       rank  rankInten rankOldAndNew                      movieNm  ...  \
# ...

# %%
df['audiAcc'].describe()
# Out:
# count    1.392000e+03
# mean     5.811442e+05
# std      1.626874e+06
# min      2.590000e+02
# 25%      8.688750e+03
# 50%      3.615800e+04
# 75%      3.102135e+05
# max      1.625258e+07
# Name: audiAcc, dtype: float64

# %%
df[df['audiAcc'] > 10000000]
# Out:
#       Unnamed: 0.2  Unnamed: 0.1   movieCd  Unnamed: 0        date  rnum  \
# 434            434           434  20148493        8484  2020-04-28     5
# 461            461           461  20183782        8508  2020-04-30     9
# 490            490           490  20184889        8557  2020-05-05     8
# 555            555           555  20177478        8549  2020-05-04    10
# 584            584           584  20150976         498  2018-02-19     9
# 621            621           621  20204548       16668  2022-07-25     9
# 840            840           840  20182530        4424  2019-03-19     5
# 872            872           872  20149120       17446  2022-10-11     7
# 920            920           920  20197803        7569  2020-01-27    10
# 955            955           955  20183867       17235  2022-09-20     6
# 1287          1287          1287  20186202        2586  2018-09-16     7
# 1326          1326          1326  20090834        1758  2018-06-25     9
#
# ...

# %%
pd.read_csv('count_dirKrNm.csv')
# Out:
#       Unnamed: 0    peopleNm  Freq
# 0              1    D.J. 카루소     1
# 1              2   F. 게리 그레이     1
# 2              3     J 블레이크슨     1
# 3              4  J.J. 에이브럼스     1
# 4              5  M. 나이트 샤말란     2
# ...          ...         ...   ...
# 1081        1082     히라야마 미호     1
# 1082        1083   히라카와 유이치로     1
# 1083        1084     히로 타카시마     1
# 1084        1085     히로키 류이치     1
# 1085        1086    히시다 마사카즈     5
#
# [1086 rows x 3 columns]
