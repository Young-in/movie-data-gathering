# %% [markdown]
# # Gathering KOBIS data

# %% [markdown]
# ## Load Libraries

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: tqdm
# Successfully installed tqdm-4.65.0

# %%
import requests
import io
import base64
import pandas as pd
import json
from tqdm import tqdm

# %% [markdown]
# ## Set common API variables

# %%
headers = {
 'Accept': 'application/json'
  }

key = "f5eef3421c602c6cb7ea224104795888"

# %% [markdown]
# ## Daily Box Office

# %%
url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json"

# %%
dfs = []
for d in tqdm(pd.date_range("2018/01/01", "2022/12/31").strftime("%Y%m%d")):
    data = {
    "key" : key, 
    "targetDt" : d,
    }

    response = requests.get(url, params = data, headers=headers)
    df = pd.DataFrame(json.loads(response.text)['boxOfficeResult']['dailyBoxOfficeList'])
    df['date'] = d
    dfs.append(df)
# Out:
# 100%|██████████| 1826/1826 [16:46<00:00,  1.81it/s]

# %%
len(dfs)
# Out:
# 1826

# %%
daily_box_office = pd.concat(dfs)
daily_box_office
# Out:
#    rnum rank rankInten rankOldAndNew   movieCd                     movieNm  \
# 0     1    1         0           OLD  20150976                   신과함께-죄와 벌
# 1     2    2         0           OLD  20170590                        1987
# 2     3    3         0           OLD  20170402                         강철비
# 3     4    4         0           OLD  20179462                      위대한 쇼맨
# 4     5    5         0           OLD  20174965           극장판 포켓몬스터 너로 정했다!
# ..  ...  ...       ...           ...       ...                         ...
# 5     6    6         0           OLD  20228640     신비아파트 극장판 차원도깨비와 7개의 세계
# 6     7    7         0           NEW  20215315                         스위치
# 7     8    8        -1           OLD  20228829  눈의 여왕5: 스노우 프린세스와 미러랜드의 비밀
# 8     9    9        -1           OLD  20227925          몬스터 신부: 101번째 프로포즈
# 9    10   10        -1           OLD  20228308    극장판 뽀로로와 친구들: 바이러스를 없애줘!
#
#         openDt    salesAmt salesShare  salesInten salesChange     salesAcc  \
# 0   2017-12-20  7715149100       52.9  -853021100         -10  76065645532
# 1   2017-12-27  4460462100       30.6  -224621200        -4.8  19714466137
# 2   2017-12-14   944228600        6.5   -48816300        -4.9  32939126166
# 3   2017-12-20   509947700        3.5    25348100         5.2   7166974900
# 4   2017-12-21   262886500        1.8    -7375400        -2.7   3380416200
# ..         ...         ...        ...         ...         ...          ...
# 5   2022-12-14   188096008        1.8    89649287        91.1   3417319076
# 6   2023-01-04   106467884        1.0   106467884         100    220588884
# 7   2022-12-22    84996568        0.8    20166085        31.1   1093855619
# 8   2022-12-28    59368300        0.6    17636000        42.3    190485000
# 9   2022-12-01    44042000        0.4    12717900        40.6   1740432400
#
#    audiCnt audiInten audiChange  audiAcc scrnCnt showCnt      date
# 0   916652   -107305      -10.5  9456147    1644    7957  20180101
# 1   531469    -28577       -5.1  2473546    1097    4982  20180101
# 2   114298     -6548       -5.4  4128591     602    1451  20180101
# 3    60070      2402        4.2   874655     432     843  20180101
# 4    34103     -1037         -3   449358     417     605  20180101
# ..     ...       ...        ...      ...     ...     ...       ...
# 5    19955      9293       87.2   356783     490     635  20221231
# 6    10579     10579        100    23148     412     562  20221231
# 7     9136      2067       29.2   118023     346     406  20221231
# 8     6308      1868       42.1    21038     226     292  20221231
# 9     4699      1300       38.2   193344     119     150  20221231
#
# [18260 rows x 19 columns]

# %%
daily_box_office.to_csv('daily_box_office.csv')

# %% [markdown]
# ## Weekly Box Office (weekend: Fri, Sat, Sun)

# %%
url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json"

# %%
dfs = []
for d in tqdm(pd.date_range("2018/01/01", "2022/12/31", freq = "W").strftime("%Y%m%d")):
    data = {
    "key" : key, 
    "targetDt" : d,
    }

    response = requests.get(url, params = data, headers=headers)
    df = pd.DataFrame(json.loads(response.text)['boxOfficeResult']['weeklyBoxOfficeList'])
    df['date'] = d
    dfs.append(df)
# Out:
# 100%|██████████| 260/260 [03:54<00:00,  1.11it/s]

# %%
weekly_box_office = pd.concat(dfs)
weekly_box_office
# Out:
#    rnum rank rankInten rankOldAndNew   movieCd                      movieNm  \
# 0     1    1         0           OLD  20150976                    신과함께-죄와 벌
# 1     2    2         0           OLD  20170590                         1987
# 2     3    3         0           NEW  20171909                  쥬만지: 새로운 세계
# 3     4    4         0           NEW  20177104                        페르디난드
# 4     5    5        -2           OLD  20170402                          강철비
# ..  ...  ...       ...           ...       ...                          ...
# 5     6    6         0           NEW  20228829   눈의 여왕5: 스노우 프린세스와 미러랜드의 비밀
# 6     7    7        36           OLD  20228309  핑크퐁 시네마 콘서트 2: 원더스타 콘서트 대작전
# 7     8    8        -2           OLD  20228308     극장판 뽀로로와 친구들: 바이러스를 없애줘!
# 8     9    9        -4           OLD  20210364                           탄생
# 9    10   10        -2           OLD  20227445                    원피스 필름 레드
#
#         openDt     salesAmt salesShare   salesInten salesChange     salesAcc  \
# 0   2017-12-20  11047975705       36.4  -9491237208       -46.2  92571580337
# 1   2017-12-27   8919543895       29.4  -2401051542       -21.2  32847722932
# 2   2018-01-03   5557904150       18.3   5557904150       100.0   7342405650
# 3   2018-01-03   1886998500        6.2   1886998500       100.0   2625604300
# 4   2017-12-14    998370700        3.3  -1394704944       -58.3  34705414466
# ..         ...          ...        ...          ...         ...          ...
# 5   2022-12-22    655073067        1.9    655073067       100.0    715363766
# 6   2022-12-21    213626979        0.6    211626979     10581.3    249894974
# 7   2022-12-01    107517600        0.3    -62359400       -36.7   1578754400
# 8   2022-11-30     93002495        0.3   -161650519       -63.5   2930747491
# 9   2022-11-30     28378274        0.1    -23827143       -45.6   2038200220
#
#     audiCnt audiInten audiChange   audiAcc scrnCnt showCnt      date
# 0   1318754  -1146248      -46.5  11502259    1260   16497  20180107
# 1   1060097   -293609      -21.7   4089298    1094   14006  20180107
# 2    659519    659519      100.0    894544     791    9557  20180107
# 3    247007    247007      100.0    355767     698    4388  20180107
# 4    119809   -171616      -58.9   4350728     495    2938  20180107
# ..      ...       ...        ...       ...     ...     ...       ...
# 5     67729     67729      100.0     75248     626    2136  20221225
# 6     22112     21912    10956.0     26490     432    1201  20221225
# 7     11332     -7094      -38.5    175473     114     299  20221225
# 8      9600    -17403      -64.4    325724      99     332  20221225
# 9      2648     -2259      -46.0    190603      20      73  20221225
#
# [2600 rows x 19 columns]

# %%
weekly_box_office.to_csv('weekly_box_office.csv')

# %% [markdown]
# ## Movie List

# %%
url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json"

# %%
dfs = []

for p in tqdm(range((9358 // 10) + 1)):
    data = {
        "key": key,
        "curPage": p + 1,
        "openStartDt": '2018',
        "openEndDt": '2022',
    }

    response = requests.get(url, params = data, headers = headers)
    df = pd.DataFrame(json.loads(response.text)['movieListResult']['movieList'])
    dfs.append(df)

movie_list = pd.concat(dfs)
movie_list
# Out:
# 100%|██████████| 936/936 [04:06<00:00,  3.80it/s]
#      movieCd          movieNm                          movieNmEn prdtYear  \
# 0   20182280               졸업                         Graduation     2018
# 1   20183772              태일이                        Chun Tae-il     2021
# 2   20192462  마리아 칼라스: 세기의 디바  Maria by Callas: In Her Own Words     2017
# 3   20219337    1975 킬링필드, 푸난                              Funan     2018
# 4   20196655      존 윅 3: 파라벨룸  John Wick: Chapter 3 - Parabellum     2019
# ..       ...              ...                                ...      ...
# 3   20161724         스타박'스 다방                   Bittersweet Brew     2016
# 4   20173547            다운사이징                         Downsizing     2017
# 5   20175812            아오 오니              Ao Oni: The Animation     2017
# 6   20177104            페르디난드                          FERDINAND     2017
# 7   20171909      쥬만지: 새로운 세계     Jumanji: Welcome to the Jungle     2017
#
#       openDt typeNm prdtStatNm nationAlt        genreAlt repNationNm  \
# 0   20191107     장편         개봉        한국           다큐멘터리          한국
# 1   20211201     장편         개봉        한국           애니메이션          한국
# 2   20190711     장편         개봉       프랑스           다큐멘터리         프랑스
# 3   20220127     장편         개봉       프랑스       애니메이션,드라마         프랑스
# 4   20190626     장편         개봉        미국       액션,범죄,스릴러          미국
# ..       ...    ...        ...       ...             ...         ...
# 3   20180111     장편         개봉        한국         코미디,드라마          한국
# 4   20180111     장편         개봉        미국         드라마,코미디          미국
# 5   20180104     장편         개봉        일본    애니메이션,공포(호러)          일본
# 6   20180103     장편         개봉        미국  애니메이션,어드벤처,코미디          미국
# 7   20180103     장편         개봉        미국         액션,어드벤처          미국
#
#    repGenreNm                   directors  \
# 0       다큐멘터리       [{'peopleNm': '박주환'}]
# 1       애니메이션       [{'peopleNm': '홍준표'}]
# 2       다큐멘터리      [{'peopleNm': '톰 볼프'}]
# 3       애니메이션      [{'peopleNm': '드니 도'}]
# 4          액션  [{'peopleNm': '채드 스타헬스키'}]
# ..        ...                         ...
# 3         코미디       [{'peopleNm': '이상우'}]
# 4         드라마   [{'peopleNm': '알렉산더 페인'}]
# 5       애니메이션  [{'peopleNm': '하마무라 토시로'}]
# 6       애니메이션  [{'peopleNm': '카를로스 살다나'}]
# 7          액션   [{'peopleNm': '제이크 캐스단'}]
#
#                                              companys
# 0   [{'companyCd': '20230135', 'companyNm': '미디어나무...
# 1   [{'companyCd': '20100545', 'companyNm': '(주)명필...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 3   [{'companyCd': '20040209', 'companyNm': '영화사 온...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
#
# [9358 rows x 13 columns]

# %%
movie_list.to_csv('movie_list.csv', index = False)

# %% [markdown]
# ## Movie Info

# %%
movie_list = pd.read_csv('movie_list.csv')
movie_list
# Out:
#        movieCd          movieNm                          movieNmEn  prdtYear  \
# 0     20182280               졸업                         Graduation    2018.0
# 1     20183772              태일이                        Chun Tae-il    2021.0
# 2     20192462  마리아 칼라스: 세기의 디바  Maria by Callas: In Her Own Words    2017.0
# 3     20219337    1975 킬링필드, 푸난                              Funan    2018.0
# 4     20196655      존 윅 3: 파라벨룸  John Wick: Chapter 3 - Parabellum    2019.0
# ...        ...              ...                                ...       ...
# 9353  20161724         스타박'스 다방                   Bittersweet Brew    2016.0
# 9354  20173547            다운사이징                         Downsizing    2017.0
# 9355  20175812            아오 오니              Ao Oni: The Animation    2017.0
# 9356  20177104            페르디난드                          FERDINAND    2017.0
# 9357  20171909      쥬만지: 새로운 세계     Jumanji: Welcome to the Jungle    2017.0
#
#         openDt typeNm prdtStatNm nationAlt        genreAlt repNationNm  \
# 0     20191107     장편         개봉        한국           다큐멘터리          한국
# 1     20211201     장편         개봉        한국           애니메이션          한국
# 2     20190711     장편         개봉       프랑스           다큐멘터리         프랑스
# 3     20220127     장편         개봉       프랑스       애니메이션,드라마         프랑스
# 4     20190626     장편         개봉        미국       액션,범죄,스릴러          미국
# ...        ...    ...        ...       ...             ...         ...
# 9353  20180111     장편         개봉        한국         코미디,드라마          한국
# 9354  20180111     장편         개봉        미국         드라마,코미디          미국
# 9355  20180104     장편         개봉        일본    애니메이션,공포(호러)          일본
# 9356  20180103     장편         개봉        미국  애니메이션,어드벤처,코미디          미국
# 9357  20180103     장편         개봉        미국         액션,어드벤처          미국
#
#      repGenreNm                   directors  \
# 0         다큐멘터리       [{'peopleNm': '박주환'}]
# 1         애니메이션       [{'peopleNm': '홍준표'}]
# 2         다큐멘터리      [{'peopleNm': '톰 볼프'}]
# 3         애니메이션      [{'peopleNm': '드니 도'}]
# 4            액션  [{'peopleNm': '채드 스타헬스키'}]
# ...         ...                         ...
# 9353        코미디       [{'peopleNm': '이상우'}]
# 9354        드라마   [{'peopleNm': '알렉산더 페인'}]
# 9355      애니메이션  [{'peopleNm': '하마무라 토시로'}]
# 9356      애니메이션  [{'peopleNm': '카를로스 살다나'}]
# 9357         액션   [{'peopleNm': '제이크 캐스단'}]
#
#                                                companys
# 0     [{'companyCd': '20230135', 'companyNm': '미디어나무...
# 1     [{'companyCd': '20100545', 'companyNm': '(주)명필...
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 9353  [{'companyCd': '20040209', 'companyNm': '영화사 온...
# 9354                                                 []
# 9355                                                 []
# 9356                                                 []
# 9357                                                 []
#
# [9358 rows x 13 columns]

# %%
url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json"

# %%
dfs = []

for movieCd in tqdm(movie_list['movieCd']):
    data = {
        "key": key,
        "movieCd": movieCd,
    }
    
    response = requests.get(url, params = data, headers = headers)
    df = pd.DataFrame({k: [v] for k, v in json.loads(response.text)['movieInfoResult']['movieInfo'].items()})
    dfs.append(df)
movie_info = pd.concat(dfs)
movie_info
# Out:
#   3%|▎         | 237/9358 [00:58<37:21,  4.07it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 9
#       3 for movieCd in tqdm(movie_list['movieCd']):
#       4     data = {
#       5         "key": key,
#       6         "movieCd": movieCd,
#       7     }
# ----> 9     response = requests.get(url, params = data, headers = headers)
#      10     df = pd.DataFrame({k: [v] for k, v in json.loads(response.text)['movieInfoResult']['movieInfo'].items()})
#      11     dfs.append(df)
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File d:\anaconda3\envs\Python\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File d:\anaconda3\envs\Python\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File d:\anaconda3\envs\Python\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File d:\anaconda3\envs\Python\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File d:\anaconda3\envs\Python\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File d:\anaconda3\envs\Python\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File d:\anaconda3\envs\Python\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
movie_info.to_csv('movie_info.csv')

# %% [markdown]
# ## Company List

# %%
url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/company/searchCompanyList.json"

# %%
dfs = []

for p in tqdm(range((12966 // 10) + 1)):
    data = {
        "key": key,
        "curPage": p + 1,
    }

    response = requests.get(url, params = data, headers = headers)
    df = pd.DataFrame(json.loads(response.text)['companyListResult']['companyList'])
    dfs.append(df)

company_list = pd.concat(dfs)
company_list
# Out:
# 100%|██████████| 1297/1297 [04:47<00:00,  4.52it/s]
#    companyCd companyNm     companyNmEn companyPartNames ceoNm      filmoNames
# 0   20230136      미디어톡                              제작사   유정현        소녀작가 입문기
# 1   20124975   (주)미디어톡                              제작사   유정현
# 2   20203841      원더필름                              제작사   윤서영            숨비소리
# 3   20230135  미디어나무(주)  MediaNamu. Inc          제작사,배급사   김성환  수라,오늘 출가합니다,졸업
# 4   20230134  SDM스튜디오                                                 소원을 빨아봐
# ..       ...       ...             ...              ...   ...             ...
# 1   20121820       프리챌                             부가시장
# 2   20121821  하동철기념사업회                             부가시장   하준수
# 3   20121824     한아름닷컴                             부가시장
# 4   20121813     해피프랜즈                             부가시장   양영욱
# 5   20121814      헬로키노                             부가시장
#
# [12966 rows x 6 columns]

# %%
company_list.to_csv('company_list.csv', index = False)

# %% [markdown]
# ## Company Info

# %%
company_list = pd.read_csv('company_list.csv')
company_list
# Out:
#        companyCd companyNm     companyNmEn companyPartNames ceoNm  \
# 0       20230136      미디어톡             NaN              제작사   유정현
# 1       20124975   (주)미디어톡             NaN              제작사   유정현
# 2       20203841      원더필름             NaN              제작사   윤서영
# 3       20230135  미디어나무(주)  MediaNamu. Inc          제작사,배급사   김성환
# 4       20230134  SDM스튜디오              NaN              NaN   NaN
# ...          ...       ...             ...              ...   ...
# 12961   20121820       프리챌             NaN             부가시장   NaN
# 12962   20121821  하동철기념사업회             NaN             부가시장   하준수
# 12963   20121824     한아름닷컴             NaN             부가시장   NaN
# 12964   20121813     해피프랜즈             NaN             부가시장   양영욱
# 12965   20121814      헬로키노             NaN             부가시장   NaN
#
#            filmoNames
# 0            소녀작가 입문기
# 1                 NaN
# 2                숨비소리
# 3      수라,오늘 출가합니다,졸업
# 4             소원을 빨아봐
# ...               ...
# 12961             NaN
# 12962             NaN
# 12963             NaN
# 12964             NaN
# 12965             NaN
#
# [12966 rows x 6 columns]

# %%
url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/company/searchCompanyInfo.json"

# %%
dfs = []

for companyCd in tqdm(company_list['companyCd']):
    data = {
        "key": key,
        "companyCd": companyCd,
    }

    response = requests.get(url, params = data, headers = headers)
    df = pd.DataFrame({k: [v] for k, v in json.loads(response.text)['companyInfoResult']['companyInfo'].items()})
    dfs.append(df)

company_info = pd.concat(dfs)
company_info
# Out:
#   1%|          | 69/12966 [00:13<40:49,  5.27it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 9
#       3 for companyCd in tqdm(company_list['companyCd']):
#       4     data = {
#       5         "key": key,
#       6         "companyCd": companyCd,
#       7     }
# ----> 9     response = requests.get(url, params = data, headers = headers)
#      10     df = pd.DataFrame({k: [v] for k, v in json.loads(response.text)['companyInfoResult']['companyInfo'].items()})
#      11     dfs.append(df)
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File d:\anaconda3\envs\Python\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File d:\anaconda3\envs\Python\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File d:\anaconda3\envs\Python\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File d:\anaconda3\envs\Python\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File d:\anaconda3\envs\Python\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File d:\anaconda3\envs\Python\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File d:\anaconda3\envs\Python\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
company_info.to_csv('company_info.csv')

# %% [markdown]
# ## People List

# %%
url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json"

# %%
dfs = []

for p in tqdm(range((165730 // 10) + 1)):
    data = {
        "key": key,
        "curPage": p + 1,
    }

    response = requests.get(url, params = data, headers = headers)
    df = pd.DataFrame(json.loads(response.text)['peopleListResult']['peopleList'])
    dfs.append(df)

people_list = pd.concat(dfs)
people_list
# Out:
#   2%|▏         | 343/16574 [7:00:26<331:35:54, 73.55s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 9
#       3 for p in tqdm(range((165730 // 10) + 1)):
#       4     data = {
#       5         "key": key,
#       6         "curPage": p + 1,
#       7     }
# ----> 9     response = requests.get(url, params = data, headers = headers)
#      10     df = pd.DataFrame(json.loads(response.text)['peopleListResult']['peopleList'])
#      11     dfs.append(df)
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File d:\anaconda3\envs\Python\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File d:\anaconda3\envs\Python\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File d:\anaconda3\envs\Python\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File d:\anaconda3\envs\Python\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File d:\anaconda3\envs\Python\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File d:\anaconda3\envs\Python\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File d:\anaconda3\envs\Python\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File d:\anaconda3\envs\Python\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
people_list.to_csv('people_list.csv', index = False)

# %% [markdown]
# ## People Info

# %%
people_list = pd.read_csv('people_list.csv')
people_list

# %%
url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleInfo.json"

# %%
dfs = []

for peopleCd in tqdm(people_list['peopleCd']):
    data = {
        "key": key,
        "peopleCd": peopleCd,
    }

    response = requests.get(url, params = data, headers = headers)
    df = pd.DataFrame({k: [v] for k, v in json.loads(response.text)['peopleInfoResult']['peopleInfo'].items()})
    dfs.append(df)

people_info = pd.concat(dfs)
people_info
# Out:
# 100%|██████████| 120/120 [00:21<00:00,  5.69it/s]
#     peopleCd     peopleNm            peopleNmEn   sex repRoleNm homepages  \
# 0   20388687          포스타                        None        감독        []
# 0   20216746  알레한드로 몬테베르드  Alejandro Monteverde    남자        감독        []
# 0   20388671          서유담                          남자        배우        []
# 0   20303549          유다미             YOO Da-mi    여자        배우        []
# 0   20388686          박중일          Park Jung Il    남자       조감독        []
# ..       ...          ...                   ...   ...       ...       ...
# 0   20373888          김혜강                          여자       예고편        []
# 0   20376610          조대흠                          남자       조감독        []
# 0   20388531          박나은                        None        감독        []
# 0   20311836    마메자와 마메타로                          남자        감독        []
# 0   20365239          양하영                          여자       DI팀        []
#
#                                                filmos
# 0   [{'movieCd': '20231124', 'movieNm': 'X같은 상사의 연...
# 0   [{'movieCd': '20155725', 'movieNm': '리틀 보이', '...
# 0   [{'movieCd': '20217364', 'movieNm': '이번엔 잘 되겠지...
# 0   [{'movieCd': '20183848', 'movieNm': '수상한 이웃', ...
# 0   [{'movieCd': '20227627', 'movieNm': '물꽃의 전설', ...
# ..                                                ...
# 0   [{'movieCd': '20218476', 'movieNm': '나만 보이니', ...
# 0   [{'movieCd': '20217892', 'movieNm': '식물카페, 온정'...
# 0   [{'movieCd': '20230866', 'movieNm': '그녀가 순결했던 ...
# 0   [{'movieCd': '20230315', 'movieNm': '가슴 큰 목욕탕 ...
# 0   [{'movieCd': '20223740', 'movieNm': '크리스마스 캐럴'...
#
# [120 rows x 7 columns]

# %%
people_info.to_csv('people_info.csv', index = False)
